# %%
# a. Read obama_speech.txt file and count the number of lines and words
def count_lines_and_words(filename):
    line_count = 0
    word_count = 0

    with open(filename, 'r') as file:
        for line in file:
            line_count += 1
            words = line.split()
            word_count += len(words)

    return line_count, word_count

# Corrected filename with double backslashes
filename = 'C:\\Users\\User\\Downloads\\obama_speech.txt'

# Alternatively, you can use a raw string for the filename
# filename = r'C:\Users\User\Downloads\obama_speech.txt'

lines, words = count_lines_and_words(filename)

print("Number of lines:", lines)
print("Number of words:", words)
# Out:
# Number of lines: 66
# Number of words: 2400

# %%
# b. Read obama_speech.txt file and count number of lines and words
def count_lines_and_words(filename):
    line_count = 0
    word_count = 0

    with open(filename, 'r') as file:
        for line in file:
            line_count += 1
            words = line.split()
            word_count += len(words)

    return line_count, word_count

filename = 'C:\\Users\\User\\Downloads\\michelle_obama_speech.txt'
lines, words = count_lines_and_words(filename)

print("Number of lines:", lines)
print("Number of words:", words)
# Out:
# Number of lines: 83
# Number of words: 2204

# %%
# c. Read donald_speech.txt file and count number of lines and words
def count_lines_and_words(filename):
    line_count = 0
    word_count = 0

    with open(filename, 'r') as file:
        for line in file:
            line_count += 1
            words = line.split()
            word_count += len(words)

    return line_count, word_count

filename = 'C:\\Users\\User\\Downloads\\donald_speech.txt'
lines, words = count_lines_and_words(filename)

print("Number of lines:", lines)
print("Number of words:", words)
# Out:
# Number of lines: 48
# Number of words: 1259

# %%
# d Read melina_trump_speech.txt file and count number of lines and words
def count_lines_and_words(filename):
    line_count = 0
    word_count = 0

    with open(filename, 'r') as file:
        for line in file:
            line_count += 1
            words = line.split()
            word_count += len(words)

    return line_count, word_count

filename = 'C:\\Users\\User\\Downloads\\melina_trump_speech.txt'
lines, words = count_lines_and_words(filename)

print("Number of lines:", lines)
print("Number of words:", words)
# Out:
# Number of lines: 33
# Number of words: 1375

# %%
# 2. Read the countries_data.json data file in data directory, create a function that finds the ten most 
# spoken languages

import json

def find_most_spoken_languages():
    with open('C:\\Users\\User\\Downloads\\countries_data.json', 'r', encoding='utf-8') as file:
        data = json.load(file)

    language_count = {}

    for country in data:
        languages = country['languages']

        for language in languages:
            if language in language_count:
                language_count[language] += 1
            else:
                language_count[language] = 1

    sorted_languages = sorted(language_count.items(), key=lambda x: x[1], reverse=True)
    most_spoken_languages = [language for language, count in sorted_languages[:10]]

    return most_spoken_languages

most_spoken = find_most_spoken_languages()

print("Ten most spoken languages:")
for language in most_spoken:
    print(language)
# Out:
# Ten most spoken languages:
# English
# French
# Arabic
# Spanish
# Portuguese
# Russian
# Dutch
# German
# Chinese
# Serbian

# %%
# 3. Read the countries_data.json data file in data directory, create a function that creates a list of the ten 
# most populated countries
import json

def find_most_populated_countries():
    with open('C:\\Users\\User\\Downloads\\countries_data.json', 'r', encoding='utf-8') as file:
        data = json.load(file)

    sorted_countries = sorted(data, key=lambda x: x['population'], reverse=True)
    most_populated_countries = [country['name'] for country in sorted_countries[:10]]

    return most_populated_countries

most_populated = find_most_populated_countries()

print("Ten most populated countries:")
for country in most_populated:
    print(country)
# Out:
# Ten most populated countries:
# China
# India
# United States of America
# Indonesia
# Brazil
# Pakistan
# Nigeria
# Bangladesh
# Russian Federation
# Japan

# %%
import re

def extract_incoming_email_addresses(filename):
    email_addresses = []

    with open(filename, 'r') as file:
        for line in file:
            if line.startswith
caret.cam.ac.uk
# ian@caret.cam.ac.uk
# ian@caret.cam.ac.uk
# ssmail@indiana.edu
# zqian@umich.edu
# stuart.freeman@et.gatech.edu
# dlhaines@umich.edu
# dlhaines@umich.edu
# stuart.freeman@et.gatech.edu
# chmaurer@iupui.edu
# chmaurer@iupui.edu
# cwen@iupui.edu
# cwen@iupui.edu
# cwen@iupui.edu
# ian@caret.cam.ac.uk
# dlhaines@umich.edu
# zqian@umich.edu
# zqian@umich.edu
# zqian@umich.edu
# gopal.ramasammycook@gmail.com
# dlhaines@umich.edu
# zqian@umich.edu
# ian@caret.cam.ac.uk
# aaronz@vt.edu
# john.ellis@rsmart.com
# john.ellis@rsmart.com
# aaronz@vt.edu
# cwen@iupui.edu
# zqian@umich.edu
# wagnermr@iupui.edu
# aaronz@vt.edu
# wagnermr@iupui.edu
# gopal.ramasammycook@gmail.com
# lance@indiana.edu
# sgithens@caret.cam.ac.uk
# ggolden@umich.edu
# ggolden@umich.edu
# cwen@iupui.edu
# ggolden@umich.edu
# ggolden@umich.edu
# ggolden@umich.edu
# ggolden@umich.edu
# david.horwitz@uct.ac.za
# antranig@caret.cam.ac.uk
# ian@caret.cam.ac.uk
# ian@caret.cam.ac.uk
# ian@caret.cam.ac.uk
# antranig@caret.cam.ac.uk
# ian@caret.cam.ac.uk
# ian@caret.cam.ac.uk
# ian@caret.cam.ac.uk
# david.horwitz@uct.ac.za
# ian@caret.cam.ac.uk
# aaronz@vt.edu
# aaronz@vt.edu
# rjlowe@iupui.edu
# rjlowe@iupui.edu
# rjlowe@iupui.edu
# ian@caret.cam.ac.uk
# gopal.ramasammycook@gmail.com
# ian@caret.cam.ac.uk
# david.horwitz@uct.ac.za
# gopal.ramasammycook@gmail.com
# antranig@caret.cam.ac.uk
# arwhyte@umich.edu
# arwhyte@umich.edu
# arwhyte@umich.edu
# ian@caret.cam.ac.uk
# ian@caret.cam.ac.uk
# ray@media.berkeley.edu
# ktsao@stanford.edu
# sgithens@caret.cam.ac.uk
# zqian@umich.edu
# cwen@iupui.edu
# antranig@caret.cam.ac.uk
# zqian@umich.edu
# jimeng@umich.edu
# jimeng@umich.edu
# antranig@caret.cam.ac.uk
# antranig@caret.cam.ac.uk
# ssmail@indiana.edu
# ian@caret.cam.ac.uk
# ian@caret.cam.ac.uk
# zqian@umich.edu

# %%
"""
Find the most common words in the English language. Call the name of your function find_most_common_words, 
it will take two parameters - a string or a file and a positive integer, indicating the number of words. 
Your function will return an array of tuples in descending order. Check the output
"""
import re
from collections import Counter

def find_most_common_words(data, num_words):
    # Load the list of common English words
    with open('C:\\Users\\User\\Downloads\\common_words_frequency.txt', 'r') as file:
        common_words = [word.strip() for word in file]

    # Initialize a counter to keep track of word frequencies
    word_counter = Counter()

    # Process the data based on its type: string or file
    if isinstance(data, str):
        words = re.findall(r'\b\w+\b', data.lower())
        word_counter.update(words)
    else:
        for line in data:
            words = re.findall(r'\b\w+\b', line.lower())
            word_counter.update(words)

    # Filter out non-common words and sort by frequency in descending order
    common_words = [(word, freq) for word, freq in word_counter.items() if word in common_words]
    common_words.sort(key=lambda x: x[1], reverse=True)

    # Return the specified number of most common words
    return common_words[:num_words]

# Example usage with a string
text = "This is the source of our confidence - the knowledge that God calls on us to shape an uncertain destiny."
most_common = find_most_common_words(text, 5)
print(most_common)

# Example usage with a file
filename = './sample_text.txt'
with open(filename, 'r') as file:
    most_common = find_most_common_words(file, 10)
    print(most_common)
# Out:
# []
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[21], line 40
#      38 # Example usage with a file
#      39 filename = './sample_text.txt'
# ---> 40 with open(filename, 'r') as file:
#      41     most_common = find_most_common_words(file, 10)
#      42     print(most_common)
#
# File c:\Users\User\miniconda3\envs\datascience\lib\site-packages\IPython\core\interactiveshell.py:284, in _modified_open(file, *args, **kwargs)
#     277 if file in {0, 1, 2}:
#     278     raise ValueError(
#     279         f"IPython won't let you open fd={file} by default "
#     280         "as it is likely to crash IPython. If you know what you are doing, "
#     281         "you can use builtins' open."
#     282     )
# --> 284 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: './sample_text.txt'

# %%
"""
Use the function, find_most_frequent_words to find:
   a) The ten most frequent words used in [Obama's speech]
   (https://github.com/Asabeneh/30-Days-Of-Python/blob/master/data/obama_speech.txt)
"""
import re
from collections import Counter

def find_most_common_words(data, num_words):
    words = re.findall(r'\b\w+\b', data.lower())
    word_counter = Counter(words)
    common_words = [(word, freq) for word, freq in word_counter.items()]
    common_words.sort(key=lambda x: x[1], reverse=True)
    return common_words[:num_words]

# Read Obama's speech from the file
filename = 'C:\\Users\\User\\Downloads\\obama_speech.txt'
with open(filename, 'r') as file:
    speech_text = file.read()

# Find the ten most frequent words in Obama's speech
most_frequent_words = find_most_common_words(speech_text, 10)

# Print the ten most frequent words
for word, frequency in most_frequent_words:
    print(word, frequency)
# Out:
# the 129
# and 113
# of 81
# to 70
# our 67
# we 62
# that 50
# a 48
# is 36
# in 25

# %%
"""
b) The ten most frequent words used in [Michelle's speech]
(https://github.com/Asabeneh/30-Days-Of-Python/blob/master/data/michelle_obama_speech.txt)

"""
import re
from collections import Counter

def find_most_common_words(data, num_words):
    words = re.findall(r'\b\w+\b', data.lower())
    word_counter = Counter(words)
    common_words = [(word, freq) for word, freq in word_counter.items()]
    common_words.sort(key=lambda x: x[1], reverse=True)
    return common_words[:num_words]

# Read Obama's speech from the file
filename = 'C:\\Users\\User\\Downloads\\michelle_obama_speech.txt'
with open(filename, 'r') as file:
    speech_text = file.read()

# Find the ten most frequent words in Obama's speech
most_frequent_words = find_most_common_words(speech_text, 10)

# Print the ten most frequent words
for word, frequency in most_frequent_words:
    print(word, frequency)
# Out:
# and 96
# the 85
# to 84
# that 50
# of 46
# a 41
# he 37
# in 36
# my 28
# i 28

# %%
"""
c) The ten most frequent words used in [Trump's speech]
(https://github.com/Asabeneh/30-Days-Of-Python/blob/master/data/donald_speech.txt)
"""
import re
from collections import Counter

def find_most_common_words(data, num_words):
    words = re.findall(r'\b\w+\b', data.lower())
    word_counter = Counter(words)
    common_words = [(word, freq) for word, freq in word_counter.items()]
    common_words.sort(key=lambda x: x[1], reverse=True)
    return common_words[:num_words]

# Read Obama's speech from the file
filename = 'C:\\Users\\User\\Downloads\\donald_speech.txt'
with open(filename, 'r') as file:
    speech_text = file.read()

# Find the ten most frequent words in Obama's speech
most_frequent_words = find_most_common_words(speech_text, 10)

# Print the ten most frequent words
for word, frequency in most_frequent_words:
    print(word, frequency)
# Out:
# the 65
# and 59
# we 44
# will 40
# of 38
# to 32
# our 30
# is 20
# america 17
# for 13

# %%
"""
d) The ten most frequent words used in [Melina's speech]
(https://github.com/Asabeneh/30-Days-Of-Python/blob/master/data/melina_trump_speech.txt)
"""
import re
from collections import Counter

def find_most_common_words(data, num_words):
    words = re.findall(r'\b\w+\b', data.lower())
    word_counter = Counter(words)
    common_words = [(word, freq) for word, freq in word_counter.items()]
    common_words.sort(key=lambda x: x[1], reverse=True)
    return common_words[:num_words]

# Read Obama's speech from the file
filename = 'C:\\Users\\User\\Downloads\\melina_trump_speech.txt'
with open(filename, 'r') as file:
    speech_text = file.read()

# Find the ten most frequent words in Obama's speech
most_frequent_words = find_most_common_words(speech_text, 10)

# Print the ten most frequent words
for word, frequency in most_frequent_words:
    print(word, frequency)
# Out:
# and 77
# to 55
# the 52
# is 29
# i 28
# for 27
# of 25
# that 24
# a 22
# you 21

# %%
import re
import string
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import requests

nltk.download('stopwords')
nltk.download('punkt')

def clean_text(text):
    # Remove punctuation
    text = text.translate(str.maketrans("", "", string.punctuation))

    # Convert to lowercase
    text = text.lower()

    # Remove numbers
    text = re.sub(r"\d+", "", text)

    # Remove whitespace
    text = text.strip()

    return text

def remove_stop_words(text):
    stop_words = set(stopwords.words('english'))
    tokens = word_tokenize(text)
    filtered_tokens = [word for word in tokens if word.casefold() not in stop_words]
    filtered_text = ' '.join(filtered_tokens)
    return filtered_text

def check_text_similarity(text1, text2):
    # Clean and preprocess the texts
    clean_text1 = clean_text(text1)
    clean_text2 = clean_text(text2)

    # Remove stop words
    clean_text1 = remove_stop_words(clean_text1)
    clean_text2 = remove_stop_words(clean_text2)

    # Create TF-IDF vectorizer
    vectorizer = TfidfVectorizer()

    # Fit and transform the vectorizer on the texts
    tfidf_matrix = vectorizer.fit_transform([clean_text1, clean_text2])

    # Calculate cosine similarity
    similarity_score = cosine_similarity(tfidf_matrix[0], tfidf_matrix[1])[0][0]

    return similarity_score

# URLs of the speeches
michelle_speech_url = 'https://raw.githubusercontent.com/Asabeneh/30-Days-Of-Python/master/data/michelle_obama_speech.txt'
melania_speech_url = 'https://raw.githubusercontent.com/Asabeneh/30-Days-Of-Python/master/data/melania_trump_speech.txt'

# Download speeches from URLs
michelle_speech = requests.get(michelle_speech_url).text
melania_speech = requests.get(melania_speech_url).text

# Calculate the similarity score
similarity_score = check_text_similarity(michelle_speech, melania_speech)
print(f"The similarity score between the two speeches is: {similarity_score}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[40], line 6
#       4 from nltk.corpus import stopwords
#       5 from nltk.tokenize import word_tokenize
# ----> 6 from sklearn.feature_extraction.text import TfidfVectorizer
#       7 from sklearn.metrics.pairwise import cosine_similarity
#       8 import requests
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
# 8. Find the 10 most repeated words in the romeo_and_juliet.txt

import re
from collections import Counter

# Read the content of the file
with open('C:\\Users\\User\\Downloads\\romeo_and_juliet.txt', 'r') as file:
    content = file.read()

# Remove punctuation and convert to lowercase
content = re.sub(r'[^\w\s]', '', content.lower())

# Split the content into words
words = content.split()

# Count the occurrences of each word
word_counts = Counter(words)

# Get the 10 most common words and their frequencies
top_10_words = word_counts.most_common(10)

# Print the results
print("The 10 most repeated words in 'romeo_and_juliet.txt' are:")
for word, count in top_10_words:
    print(f"{word}: {count}")
# Out:
# The 10 most repeated words in 'romeo_and_juliet.txt' are:
# the: 866
# and: 793
# to: 625
# i: 585
# of: 535
# a: 527
# in: 377
# is: 375
# that: 363
# you: 362

# %%
"""
9. Read the [hacker news csv](https://github.com/Asabeneh/30-Days-Of-Python/blob/master/data/hacker_news.csv) file and find out:
   a) Count the number of lines containing python or Python
"""
import csv

file_path = "C:\\Users\\User\\Downloads\\hacker_news.csv"

count = 0

with open(file_path, "r", encoding="utf-8") as file:
    csv_reader = csv.reader(file)
    for row in csv_reader:
        if len(row) > 2 and "python" in row[2].lower():
            count += 1

print("Number of lines containing 'python' or 'Python':", count)
# Out:
# Number of lines containing 'python' or 'Python': 101

# %%
# b) Count the number lines containing JavaScript, javascript or Javascript
import csv

file_path = "C:\\Users\\User\\Downloads\\hacker_news.csv"

count = 0

with open(file_path, "r", encoding="utf-8") as file:
    csv_reader = csv.reader(file)
    for row in csv_reader:
        try:
            if len(row) > 2 and ("JavaScript" in row[2] or "javascript" in row[2] or "Javascript" in row[2]):
                count += 1
        except IndexError:
            pass

print("Number of lines containing 'JavaScript', 'javascript', or 'Javascript':", count)
# Out:
# Number of lines containing 'JavaScript', 'javascript', or 'Javascript': 70

# %%
# c. Count the number lines containing Java and not JavaScript
import csv

file_path = "C:\\Users\\User\\Downloads\\hacker_news.csv"

count = 0

with open(file_path, "r", encoding="utf-8") as file:
    csv_reader = csv.reader(file)
    for row in csv_reader:
        if len(row) > 2 and "Java" in row[2] and "JavaScript" not in row[2]:
            count += 1

print("Number of lines containing 'Java' but not 'JavaScript':", count)
# Out:
# Number of lines containing 'Java' but not 'JavaScript': 2
